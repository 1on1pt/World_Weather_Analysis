# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tutoia
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | concepcion
# Processing Record 4 of Set 1 | amapa
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | zhigansk
# Processing Record 7 of Set 1 | chuy
# Processing Record 8 of Set 1 | guozhen
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | salalah
# Processing Record 11 of Set 1 | nanortalik
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | saint-augustin
# Processing Record 16 of Set 1 | havre-saint-pierre
# Processing Record 17 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 1 | kawalu
# Processing Record 19 of Set 1 | vao
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | kruisfontein
# Processing Record 22 of Set 1 | luderitz
# Processing Record 23 of Set 1 | bengkulu
# Processing Record 24 of Set 1 | palmer
# Processing Record 25 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 1 | touros
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | skibbereen
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | rio grande
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | katsuura
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | bar harbor
# Processing Record 39 of Set 1 | mocuba
# Processing Record 40 of Set 1 | huarmey
# Processing Record 41 of Set 1 | vila velha
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | dingle
# Processing Record 45 of Set 1 | new glasgow
# Processing Record 46 of Set 1 | leningradskiy
# Processing Record 47 of Set 1 | saint george
# Processing Record 48 of Set 1 | sorong
# Processing Record 49 of Set 1 | penzberg
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | koslan
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | finspang
# Processing Record 4 of Set 2 | darhan
# Processing Record 5 of Set 2 | san juan
# Processing Record 6 of Set 2 | gogrial
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | tura
# Processing Record 9 of Set 2 | sisimiut
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | norman wells
# Processing Record 12 of Set 2 | buala
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | powell river
# Processing Record 15 of Set 2 | cayenne
# Processing Record 16 of Set 2 | nabire
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | dubbo
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | toamasina
# Processing Record 23 of Set 2 | wattegama
# Processing Record 24 of Set 2 | pilao arcado
# City not found. Skipping...
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | goderich
# Processing Record 27 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 2 | agadir
# Processing Record 29 of Set 2 | puerto del rosario
# Processing Record 30 of Set 2 | kautokeino
# Processing Record 31 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 2 | osa
# Processing Record 33 of Set 2 | quelimane
# Processing Record 34 of Set 2 | conde
# Processing Record 35 of Set 2 | kapaa
# Processing Record 36 of Set 2 | lethem
# Processing Record 37 of Set 2 | rockingham
# Processing Record 38 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 2 | kirakira
# Processing Record 40 of Set 2 | bull savanna
# Processing Record 41 of Set 2 | longyearbyen
# Processing Record 42 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 2 | mahibadhoo
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | cidreira
# Processing Record 50 of Set 2 | lavrentiya
# Processing Record 1 of Set 3 | tabukiniberu
# City not found. Skipping...
# Processing Record 2 of Set 3 | port elizabeth
# Processing Record 3 of Set 3 | hobyo
# Processing Record 4 of Set 3 | tiksi
# Processing Record 5 of Set 3 | cherdyn
# Processing Record 6 of Set 3 | bethel
# Processing Record 7 of Set 3 | hilo
# Processing Record 8 of Set 3 | hasaki
# Processing Record 9 of Set 3 | lokosovo
# Processing Record 10 of Set 3 | arlit
# Processing Record 11 of Set 3 | burnie
# Processing Record 12 of Set 3 | mumbwa
# Processing Record 13 of Set 3 | kahului
# Processing Record 14 of Set 3 | alcantara
# Processing Record 15 of Set 3 | seoul
# Processing Record 16 of Set 3 | mapastepec
# Processing Record 17 of Set 3 | hami
# Processing Record 18 of Set 3 | omsukchan
# Processing Record 19 of Set 3 | cesky krumlov
# Processing Record 20 of Set 3 | banyo
# Processing Record 21 of Set 3 | klaksvik
# Processing Record 22 of Set 3 | kamaishi
# Processing Record 23 of Set 3 | saint-joseph
# Processing Record 24 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 3 | luanda
# Processing Record 26 of Set 3 | ixtapa
# Processing Record 27 of Set 3 | okhotsk
# Processing Record 28 of Set 3 | atuona
# Processing Record 29 of Set 3 | isangel
# Processing Record 30 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 3 | phu khieo
# City not found. Skipping...
# Processing Record 32 of Set 3 | katangli
# Processing Record 33 of Set 3 | ca mau
# Processing Record 34 of Set 3 | narsaq
# Processing Record 35 of Set 3 | sitka
# Processing Record 36 of Set 3 | priiskovyy
# Processing Record 37 of Set 3 | louga
# Processing Record 38 of Set 3 | clyde river
# Processing Record 39 of Set 3 | nchelenge
# Processing Record 40 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 3 | tshikapa
# Processing Record 42 of Set 3 | ijaki
# City not found. Skipping...
# Processing Record 43 of Set 3 | ukholovo
# Processing Record 44 of Set 3 | eyl
# Processing Record 45 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 3 | capao da canoa
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 3 | mizdah
# Processing Record 49 of Set 3 | grindavik
# Processing Record 50 of Set 3 | vardo
# Processing Record 1 of Set 4 | verkhnetulomskiy
# Processing Record 2 of Set 4 | ghogha
# Processing Record 3 of Set 4 | chistogorskiy
# Processing Record 4 of Set 4 | samarai
# Processing Record 5 of Set 4 | vila franca do campo
# Processing Record 6 of Set 4 | kerema
# Processing Record 7 of Set 4 | panguna
# Processing Record 8 of Set 4 | grand gaube
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | sabang
# Processing Record 11 of Set 4 | torbay
# Processing Record 12 of Set 4 | sambava
# Processing Record 13 of Set 4 | kodiak
# Processing Record 14 of Set 4 | bathsheba
# Processing Record 15 of Set 4 | akdepe
# Processing Record 16 of Set 4 | sinnamary
# Processing Record 17 of Set 4 | srednekolymsk
# Processing Record 18 of Set 4 | saiha
# Processing Record 19 of Set 4 | royan
# Processing Record 20 of Set 4 | warrington
# Processing Record 21 of Set 4 | anadyr
# Processing Record 22 of Set 4 | yanam
# Processing Record 23 of Set 4 | san cristobal
# Processing Record 24 of Set 4 | kingaroy
# Processing Record 25 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 4 | arkhipo-osipovka
# Processing Record 27 of Set 4 | maniitsoq
# Processing Record 28 of Set 4 | marsa matruh
# Processing Record 29 of Set 4 | egvekinot
# Processing Record 30 of Set 4 | kalengwa
# Processing Record 31 of Set 4 | wanaka
# Processing Record 32 of Set 4 | cape town
# Processing Record 33 of Set 4 | bardiyah
# Processing Record 34 of Set 4 | miles city
# Processing Record 35 of Set 4 | namalenga
# Processing Record 36 of Set 4 | lata
# Processing Record 37 of Set 4 | gladstone
# Processing Record 38 of Set 4 | saskylakh
# Processing Record 39 of Set 4 | ahuimanu
# Processing Record 40 of Set 4 | upernavik
# Processing Record 41 of Set 4 | castro
# Processing Record 42 of Set 4 | butaritari
# Processing Record 43 of Set 4 | am timan
# Processing Record 44 of Set 4 | san quintin
# Processing Record 45 of Set 4 | huittinen
# Processing Record 46 of Set 4 | sur
# Processing Record 47 of Set 4 | sao felix do xingu
# Processing Record 48 of Set 4 | cabo san lucas
# Processing Record 49 of Set 4 | thompson
# Processing Record 50 of Set 4 | lebu
# Processing Record 1 of Set 5 | mayo
# Processing Record 2 of Set 5 | ponta do sol
# Processing Record 3 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 5 | asau
# Processing Record 5 of Set 5 | hamilton
# Processing Record 6 of Set 5 | mount gambier
# Processing Record 7 of Set 5 | mehamn
# Processing Record 8 of Set 5 | moron
# Processing Record 9 of Set 5 | goundi
# Processing Record 10 of Set 5 | baruun-urt
# Processing Record 11 of Set 5 | hervey bay
# Processing Record 12 of Set 5 | kaitangata
# Processing Record 13 of Set 5 | port lincoln
# Processing Record 14 of Set 5 | sinazongwe
# Processing Record 15 of Set 5 | caravelas
# Processing Record 16 of Set 5 | marataizes
# Processing Record 17 of Set 5 | northam
# Processing Record 18 of Set 5 | alpena
# Processing Record 19 of Set 5 | neepawa
# Processing Record 20 of Set 5 | nishihara
# Processing Record 21 of Set 5 | salamiyah
# Processing Record 22 of Set 5 | guaca
# Processing Record 23 of Set 5 | richards bay
# Processing Record 24 of Set 5 | livingston
# Processing Record 25 of Set 5 | awjilah
# Processing Record 26 of Set 5 | chippewa falls
# Processing Record 27 of Set 5 | geraldton
# Processing Record 28 of Set 5 | beloha
# Processing Record 29 of Set 5 | san rafael
# Processing Record 30 of Set 5 | yenagoa
# Processing Record 31 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 5 | yerbogachen
# Processing Record 33 of Set 5 | gien
# Processing Record 34 of Set 5 | chastoozerye
# City not found. Skipping...
# Processing Record 35 of Set 5 | arman
# Processing Record 36 of Set 5 | alamosa
# Processing Record 37 of Set 5 | saurimo
# Processing Record 38 of Set 5 | pevek
# Processing Record 39 of Set 5 | buique
# Processing Record 40 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 41 of Set 5 | altos
# Processing Record 42 of Set 5 | mandan
# Processing Record 43 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 45 of Set 5 | lake city
# Processing Record 46 of Set 5 | andernach
# Processing Record 47 of Set 5 | chester
# Processing Record 48 of Set 5 | pilna
# Processing Record 49 of Set 5 | saint-philippe
# Processing Record 50 of Set 5 | iqaluit
# Processing Record 1 of Set 6 | mayor pablo lagerenza
# Processing Record 2 of Set 6 | necochea
# Processing Record 3 of Set 6 | komsomolskiy
# Processing Record 4 of Set 6 | pouembout
# Processing Record 5 of Set 6 | strezhevoy
# Processing Record 6 of Set 6 | constitucion
# Processing Record 7 of Set 6 | mount isa
# Processing Record 8 of Set 6 | victoria
# Processing Record 9 of Set 6 | lensk
# Processing Record 10 of Set 6 | baijiantan
# Processing Record 11 of Set 6 | dikson
# Processing Record 12 of Set 6 | alofi
# Processing Record 13 of Set 6 | bonthe
# Processing Record 14 of Set 6 | sandwick
# Processing Record 15 of Set 6 | ossora
# Processing Record 16 of Set 6 | sibolga
# Processing Record 17 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 6 | freeport
# Processing Record 19 of Set 6 | coquimbo
# Processing Record 20 of Set 6 | marsh harbour
# Processing Record 21 of Set 6 | makiwalo
# Processing Record 22 of Set 6 | te anau
# Processing Record 23 of Set 6 | ayan
# Processing Record 24 of Set 6 | talnakh
# Processing Record 25 of Set 6 | leshukonskoye
# Processing Record 26 of Set 6 | kefamenanu
# Processing Record 27 of Set 6 | yeppoon
# Processing Record 28 of Set 6 | itarema
# Processing Record 29 of Set 6 | bongandanga
# Processing Record 30 of Set 6 | wajima
# Processing Record 31 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 6 | beringovskiy
# Processing Record 33 of Set 6 | ulety
# Processing Record 34 of Set 6 | meulaboh
# Processing Record 35 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 37 of Set 6 | inhambane
# Processing Record 38 of Set 6 | east london
# Processing Record 39 of Set 6 | seydi
# Processing Record 40 of Set 6 | san jeronimo
# Processing Record 41 of Set 6 | jiuquan
# Processing Record 42 of Set 6 | nemuro
# Processing Record 43 of Set 6 | worland
# Processing Record 44 of Set 6 | togur
# Processing Record 45 of Set 6 | codrington
# Processing Record 46 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 6 | mandalgovi
# Processing Record 48 of Set 6 | canico
# Processing Record 49 of Set 6 | bor
# Processing Record 50 of Set 6 | lobva
# Processing Record 1 of Set 7 | batsfjord
# Processing Record 2 of Set 7 | sistranda
# Processing Record 3 of Set 7 | vilhena
# Processing Record 4 of Set 7 | tual
# Processing Record 5 of Set 7 | husavik
# Processing Record 6 of Set 7 | hambantota
# Processing Record 7 of Set 7 | etchojoa
# Processing Record 8 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 9 of Set 7 | berlevag
# Processing Record 10 of Set 7 | maragogi
# Processing Record 11 of Set 7 | sunrise manor
# Processing Record 12 of Set 7 | toungoo
# City not found. Skipping...
# Processing Record 13 of Set 7 | muscat
# Processing Record 14 of Set 7 | dourbali
# Processing Record 15 of Set 7 | saint-louis
# Processing Record 16 of Set 7 | ulladulla
# Processing Record 17 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 7 | masallatah
# Processing Record 19 of Set 7 | kangaatsiaq
# Processing Record 20 of Set 7 | porto novo
# Processing Record 21 of Set 7 | bambous virieux
# Processing Record 22 of Set 7 | faratsiho
# Processing Record 23 of Set 7 | mitsamiouli
# Processing Record 24 of Set 7 | jacksonville
# Processing Record 25 of Set 7 | aklavik
# Processing Record 26 of Set 7 | sao filipe
# Processing Record 27 of Set 7 | healdsburg
# Processing Record 28 of Set 7 | coihaique
# Processing Record 29 of Set 7 | tortoli
# Processing Record 30 of Set 7 | naze
# Processing Record 31 of Set 7 | airai
# Processing Record 32 of Set 7 | namatanai
# Processing Record 33 of Set 7 | surgut
# Processing Record 34 of Set 7 | black river
# Processing Record 35 of Set 7 | anzio
# Processing Record 36 of Set 7 | teguldet
# Processing Record 37 of Set 7 | ayni
# Processing Record 38 of Set 7 | fort wellington
# Processing Record 39 of Set 7 | nome
# Processing Record 40 of Set 7 | dongli
# Processing Record 41 of Set 7 | ormara
# Processing Record 42 of Set 7 | la union
# Processing Record 43 of Set 7 | solnechnyy
# Processing Record 44 of Set 7 | nalut
# Processing Record 45 of Set 7 | general roca
# Processing Record 46 of Set 7 | bartlesville
# Processing Record 47 of Set 7 | shabrovskiy
# Processing Record 48 of Set 7 | vama
# Processing Record 49 of Set 7 | macesu de jos
# Processing Record 50 of Set 7 | djibo
# Processing Record 1 of Set 8 | tabou
# Processing Record 2 of Set 8 | krasnorechenskiy
# Processing Record 3 of Set 8 | chapais
# Processing Record 4 of Set 8 | tomatlan
# Processing Record 5 of Set 8 | port macquarie
# Processing Record 6 of Set 8 | fougamou
# Processing Record 7 of Set 8 | bilma
# Processing Record 8 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 8 | luoyang
# Processing Record 10 of Set 8 | jos
# Processing Record 11 of Set 8 | udachnyy
# Processing Record 12 of Set 8 | odawara
# Processing Record 13 of Set 8 | brae
# Processing Record 14 of Set 8 | los llanos de aridane
# Processing Record 15 of Set 8 | imeni poliny osipenko
# Processing Record 16 of Set 8 | quatre cocos
# Processing Record 17 of Set 8 | douentza
# Processing Record 18 of Set 8 | kroya
# Processing Record 19 of Set 8 | palimbang
# Processing Record 20 of Set 8 | hofn
# Processing Record 21 of Set 8 | kon tum
# Processing Record 22 of Set 8 | nelson bay
# Processing Record 23 of Set 8 | pechenga
# Processing Record 24 of Set 8 | marawi
# Processing Record 25 of Set 8 | nago
# Processing Record 26 of Set 8 | juneau
# Processing Record 27 of Set 8 | sokoni
# Processing Record 28 of Set 8 | north bend
# Processing Record 29 of Set 8 | cherskiy
# Processing Record 30 of Set 8 | cam ranh
# Processing Record 31 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 8 | santo antonio do taua
# Processing Record 33 of Set 8 | esperance
# Processing Record 34 of Set 8 | sabha
# Processing Record 35 of Set 8 | nuevo progreso
# Processing Record 36 of Set 8 | saint-pierre
# Processing Record 37 of Set 8 | wukari
# Processing Record 38 of Set 8 | chulumani
# Processing Record 39 of Set 8 | ambon
# Processing Record 40 of Set 8 | byron bay
# Processing Record 41 of Set 8 | connersville
# Processing Record 42 of Set 8 | fortuna
# Processing Record 43 of Set 8 | olafsvik
# Processing Record 44 of Set 8 | asfi
# Processing Record 45 of Set 8 | fortuna foothills
# Processing Record 46 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 8 | belyy yar
# Processing Record 48 of Set 8 | mutoko
# Processing Record 49 of Set 8 | verkhoyansk
# Processing Record 50 of Set 8 | kyzyl-suu
# Processing Record 1 of Set 9 | beyneu
# Processing Record 2 of Set 9 | severo-kurilsk
# Processing Record 3 of Set 9 | cuamba
# Processing Record 4 of Set 9 | kavieng
# Processing Record 5 of Set 9 | lompoc
# Processing Record 6 of Set 9 | berezovyy
# Processing Record 7 of Set 9 | ayorou
# Processing Record 8 of Set 9 | mangrol
# Processing Record 9 of Set 9 | kolokani
# Processing Record 10 of Set 9 | la rioja
# Processing Record 11 of Set 9 | tjome
# Processing Record 12 of Set 9 | tucuman
# Processing Record 13 of Set 9 | notre-dame-du-lac
# Processing Record 14 of Set 9 | chokurdakh
# Processing Record 15 of Set 9 | christchurch
# Processing Record 16 of Set 9 | khandbari
# Processing Record 17 of Set 9 | jiwani
# Processing Record 18 of Set 9 | port hedland
# Processing Record 19 of Set 9 | yokadouma
# Processing Record 20 of Set 9 | merzifon
# Processing Record 21 of Set 9 | kudahuvadhoo
# Processing Record 22 of Set 9 | jardim
# Processing Record 23 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 9 | manzhouli
# Processing Record 25 of Set 9 | rawson
# Processing Record 26 of Set 9 | boguchany
# Processing Record 27 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 9 | aquiraz
# Processing Record 29 of Set 9 | deputatskiy
# Processing Record 30 of Set 9 | lorengau
# Processing Record 31 of Set 9 | louis trichardt
# Processing Record 32 of Set 9 | moose factory
# Processing Record 33 of Set 9 | mana
# Processing Record 34 of Set 9 | cockburn town
# Processing Record 35 of Set 9 | ratzeburg
# Processing Record 36 of Set 9 | kalmunai
# Processing Record 37 of Set 9 | yar-sale
# Processing Record 38 of Set 9 | chicama
# Processing Record 39 of Set 9 | carora
# Processing Record 40 of Set 9 | paka
# Processing Record 41 of Set 9 | boqueirao
# Processing Record 42 of Set 9 | boa vista
# Processing Record 43 of Set 9 | jinchang
# Processing Record 44 of Set 9 | charters towers
# Processing Record 45 of Set 9 | atherton
# Processing Record 46 of Set 9 | tautira
# Processing Record 47 of Set 9 | mar del plata
# Processing Record 48 of Set 9 | dunedin
# Processing Record 49 of Set 9 | san policarpo
# Processing Record 50 of Set 9 | high level
# Processing Record 1 of Set 10 | gigmoto
# Processing Record 2 of Set 10 | shangqiu
# Processing Record 3 of Set 10 | ola
# Processing Record 4 of Set 10 | la cruz
# Processing Record 5 of Set 10 | ust-kuyga
# Processing Record 6 of Set 10 | chake chake
# Processing Record 7 of Set 10 | pochutla
# Processing Record 8 of Set 10 | sirjan
# Processing Record 9 of Set 10 | taltal
# Processing Record 10 of Set 10 | ajaccio
# Processing Record 11 of Set 10 | haines junction
# Processing Record 12 of Set 10 | basoko
# Processing Record 13 of Set 10 | wa
# City not found. Skipping...
# Processing Record 14 of Set 10 | karratha
# Processing Record 15 of Set 10 | sechura
# Processing Record 16 of Set 10 | avera
# Processing Record 17 of Set 10 | faanui
# Processing Record 18 of Set 10 | champerico
# Processing Record 19 of Set 10 | oranjestad
# Processing Record 20 of Set 10 | balkhash
# Processing Record 21 of Set 10 | turayf
# Processing Record 22 of Set 10 | marystown
# Processing Record 23 of Set 10 | tarashcha
# Processing Record 24 of Set 10 | tilichiki
# Processing Record 25 of Set 10 | stepnyak
# Processing Record 26 of Set 10 | flinders
# Processing Record 27 of Set 10 | inuvik
# Processing Record 28 of Set 10 | camaqua
# Processing Record 29 of Set 10 | arrecife
# Processing Record 30 of Set 10 | parfenyevo
# Processing Record 31 of Set 10 | xining
# Processing Record 32 of Set 10 | puerto leguizamo
# Processing Record 33 of Set 10 | saint-paul
# Processing Record 34 of Set 10 | novoagansk
# Processing Record 35 of Set 10 | lagoa
# Processing Record 36 of Set 10 | gat
# Processing Record 37 of Set 10 | wenling
# Processing Record 38 of Set 10 | sulechow
# Processing Record 39 of Set 10 | gibara
# Processing Record 40 of Set 10 | okato
# Processing Record 41 of Set 10 | kozan
# Processing Record 42 of Set 10 | kysyl-syr
# Processing Record 43 of Set 10 | camopi
# Processing Record 44 of Set 10 | parys
# Processing Record 45 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 10 | kenitra
# Processing Record 47 of Set 10 | mwene-ditu
# Processing Record 48 of Set 10 | kloulklubed
# Processing Record 49 of Set 10 | victor harbor
# Processing Record 50 of Set 10 | salinopolis
# Processing Record 1 of Set 11 | rio cauto
# Processing Record 2 of Set 11 | skjervoy
# Processing Record 3 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 4 of Set 11 | rio gallegos
# Processing Record 5 of Set 11 | merauke
# Processing Record 6 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 11 | la ronge
# Processing Record 8 of Set 11 | domoni
# Processing Record 9 of Set 11 | bjornevatn
# Processing Record 10 of Set 11 | phrai bung
# City not found. Skipping...
# Processing Record 11 of Set 11 | staraya poltavka
# Processing Record 12 of Set 11 | valday
# Processing Record 13 of Set 11 | contai
# Processing Record 14 of Set 11 | tsentralnyy
# City not found. Skipping...
# Processing Record 15 of Set 11 | aitape
# Processing Record 16 of Set 11 | iquitos
# Processing Record 17 of Set 11 | caronport
# Processing Record 18 of Set 11 | zhezkazgan
# Processing Record 19 of Set 11 | noumea
# Processing Record 20 of Set 11 | monrovia
# Processing Record 21 of Set 11 | balaipungut
# Processing Record 22 of Set 11 | sokoto
# Processing Record 23 of Set 11 | bakel
# Processing Record 24 of Set 11 | cap malheureux
# Processing Record 25 of Set 11 | bubaque
# Processing Record 26 of Set 11 | gambela
# Processing Record 27 of Set 11 | nyurba
# Processing Record 28 of Set 11 | buchanan
# Processing Record 29 of Set 11 | wexford
# Processing Record 30 of Set 11 | bereda
# Processing Record 31 of Set 11 | ingham
# Processing Record 32 of Set 11 | dongsheng
# Processing Record 33 of Set 11 | daru
# Processing Record 34 of Set 11 | wenzhou
# Processing Record 35 of Set 11 | goalpara
# Processing Record 36 of Set 11 | warangal
# Processing Record 37 of Set 11 | santiago de cao
# Processing Record 38 of Set 11 | ancud
# Processing Record 39 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 11 | sarahan
# Processing Record 41 of Set 11 | orange cove
# Processing Record 42 of Set 11 | turukhansk
# Processing Record 43 of Set 11 | rundu
# Processing Record 44 of Set 11 | paignton
# Processing Record 45 of Set 11 | bridlington
# Processing Record 46 of Set 11 | doha
# Processing Record 47 of Set 11 | vanderhoof
# Processing Record 48 of Set 11 | izhma
# Processing Record 49 of Set 11 | gizo
# Processing Record 50 of Set 11 | najran
# Processing Record 1 of Set 12 | taoudenni
# Processing Record 2 of Set 12 | tefe
# Processing Record 3 of Set 12 | crotone
# Processing Record 4 of Set 12 | jawhar
# Processing Record 5 of Set 12 | nara
# Processing Record 6 of Set 12 | kuytun
# Processing Record 7 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 8 of Set 12 | auch
# Processing Record 9 of Set 12 | aykhal
# Processing Record 10 of Set 12 | broome
# Processing Record 11 of Set 12 | sao joao da barra
# Processing Record 12 of Set 12 | novo aripuana
# Processing Record 13 of Set 12 | sarkand
# Processing Record 14 of Set 12 | paamiut
# Processing Record 15 of Set 12 | apatity
# Processing Record 16 of Set 12 | kovylkino
# Processing Record 17 of Set 12 | shelburne
# Processing Record 18 of Set 12 | rurrenabaque
# Processing Record 19 of Set 12 | hualmay
# Processing Record 20 of Set 12 | banda aceh
# Processing Record 21 of Set 12 | port hardy
# Processing Record 22 of Set 12 | diego de almagro
# Processing Record 23 of Set 12 | padang
# Processing Record 24 of Set 12 | arkhangelsk
# Processing Record 25 of Set 12 | tuatapere
# Processing Record 26 of Set 12 | tunceli
# Processing Record 27 of Set 12 | fare
# Processing Record 28 of Set 12 | dhidhdhoo
# Processing Record 29 of Set 12 | hamada
# Processing Record 30 of Set 12 | koungheul
# Processing Record 31 of Set 12 | barra patuca
# Processing Record 32 of Set 12 | mitu
# Processing Record 33 of Set 12 | rayagada
# Processing Record 34 of Set 12 | ponta delgada
# Processing Record 35 of Set 12 | lodja
# Processing Record 36 of Set 12 | mudyuga
# City not found. Skipping...
# Processing Record 37 of Set 12 | sorland
# Processing Record 38 of Set 12 | coahuayana
# Processing Record 39 of Set 12 | wewak
# Processing Record 40 of Set 12 | muros
# Processing Record 41 of Set 12 | abu samrah
# Processing Record 42 of Set 12 | matamoros
# Processing Record 43 of Set 12 | beckley
# Processing Record 44 of Set 12 | bergen
# Processing Record 45 of Set 12 | kamenka
# Processing Record 46 of Set 12 | ilulissat
# Processing Record 47 of Set 12 | pacific grove
# Processing Record 48 of Set 12 | along
# Processing Record 49 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 50 of Set 12 | southbridge
# Processing Record 1 of Set 13 | west wendover
# Processing Record 2 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 3 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 4 of Set 13 | ayagoz
# Processing Record 5 of Set 13 | north myrtle beach
# Processing Record 6 of Set 13 | barcelos
# Processing Record 7 of Set 13 | bahar
# Processing Record 8 of Set 13 | kimbe
# Processing Record 9 of Set 13 | camana
# Processing Record 10 of Set 13 | yakeshi
# Processing Record 11 of Set 13 | taua
# Processing Record 12 of Set 13 | maketu
# Processing Record 13 of Set 13 | port blair
# Processing Record 14 of Set 13 | sundby
# Processing Record 15 of Set 13 | sangar
# Processing Record 16 of Set 13 | pasighat
# Processing Record 17 of Set 13 | sembakung
# Processing Record 18 of Set 13 | safi
# Processing Record 19 of Set 13 | rorvik
# Processing Record 20 of Set 13 | san gavino monreale
# Processing Record 21 of Set 13 | maralal
# Processing Record 22 of Set 13 | stettler
# Processing Record 23 of Set 13 | jiangyou
# Processing Record 24 of Set 13 | san patricio
# Processing Record 25 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 26 of Set 13 | yinchuan
# Processing Record 27 of Set 13 | iquique
# Processing Record 28 of Set 13 | easley
# Processing Record 29 of Set 13 | wanning
# Processing Record 30 of Set 13 | guerrero negro
# Processing Record 31 of Set 13 | bambanglipuro
# Processing Record 32 of Set 13 | suleja
# Processing Record 33 of Set 13 | treinta y tres
# Processing Record 34 of Set 13 | shihezi
# Processing Record 35 of Set 13 | nimaparha
# Processing Record 36 of Set 13 | llanes
# Processing Record 37 of Set 13 | aldan
# Processing Record 38 of Set 13 | henderson
# Processing Record 39 of Set 13 | grand forks
# Processing Record 40 of Set 13 | valente
# Processing Record 41 of Set 13 | kavaratti
# Processing Record 42 of Set 13 | gobo
# Processing Record 43 of Set 13 | chiradzulu
# Processing Record 44 of Set 13 | henties bay
# Processing Record 45 of Set 13 | oron
# Processing Record 46 of Set 13 | ocos
# Processing Record 47 of Set 13 | lesnoy
# Processing Record 48 of Set 13 | kingman
# Processing Record 49 of Set 13 | palu
# Processing Record 50 of Set 13 | isiro
# Processing Record 1 of Set 14 | nova granada
# Processing Record 2 of Set 14 | bima
# Processing Record 3 of Set 14 | amparai
# City not found. Skipping...
# Processing Record 4 of Set 14 | kaeo
# Processing Record 5 of Set 14 | portobelo
# Processing Record 6 of Set 14 | burriana
# Processing Record 7 of Set 14 | parkersburg
# Processing Record 8 of Set 14 | wanxian
# Processing Record 9 of Set 14 | hobbs
# Processing Record 10 of Set 14 | krasnoselkup
# Processing Record 11 of Set 14 | tougan
# Processing Record 12 of Set 14 | kota kinabalu
# Processing Record 13 of Set 14 | augusta
# Processing Record 14 of Set 14 | san jose de sisa
# Processing Record 15 of Set 14 | harlingen
# Processing Record 16 of Set 14 | kristiansund
# Processing Record 17 of Set 14 | port hawkesbury
# Processing Record 18 of Set 14 | tonota
# Processing Record 19 of Set 14 | vanavara
# Processing Record 20 of Set 14 | cubuk
# Processing Record 21 of Set 14 | saldanha
# Processing Record 22 of Set 14 | san andres
# Processing Record 23 of Set 14 | asayita
# City not found. Skipping...
# Processing Record 24 of Set 14 | ghanzi
# Processing Record 25 of Set 14 | pontianak
# Processing Record 26 of Set 14 | kieta
# Processing Record 27 of Set 14 | havoysund
# Processing Record 28 of Set 14 | gornopravdinsk
# Processing Record 29 of Set 14 | praia da vitoria
# Processing Record 30 of Set 14 | otuzco
# Processing Record 31 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 14 | kalamazoo
# Processing Record 33 of Set 14 | kachiry
# Processing Record 34 of Set 14 | bure
# Processing Record 35 of Set 14 | abu dhabi
# Processing Record 36 of Set 14 | nigde
# Processing Record 37 of Set 14 | benguela
# Processing Record 38 of Set 14 | haines city
# Processing Record 39 of Set 14 | santa maria del rio
# Processing Record 40 of Set 14 | yulara
# Processing Record 41 of Set 14 | vaitape
# Processing Record 42 of Set 14 | zabol
# Processing Record 43 of Set 14 | manaure
# Processing Record 44 of Set 14 | broken hill
# Processing Record 45 of Set 14 | iskateley
# Processing Record 46 of Set 14 | serebryanyy bor
# Processing Record 47 of Set 14 | ostrovnoy
# Processing Record 48 of Set 14 | roma
# Processing Record 49 of Set 14 | svetlogorsk
# Processing Record 50 of Set 14 | raga
# Processing Record 1 of Set 15 | nantucket
# Processing Record 2 of Set 15 | tokonou
# Processing Record 3 of Set 15 | barrhead
# Processing Record 4 of Set 15 | rohnert park
# Processing Record 5 of Set 15 | den helder
# Processing Record 6 of Set 15 | mancio lima
# Processing Record 7 of Set 15 | cilegon
# Processing Record 8 of Set 15 | almaznyy
# Processing Record 9 of Set 15 | novyy urengoy
# Processing Record 10 of Set 15 | peleduy
# Processing Record 11 of Set 15 | wroclaw
# Processing Record 12 of Set 15 | estacion coahuila
# Processing Record 13 of Set 15 | nuuk
# Processing Record 14 of Set 15 | kabansk
# Processing Record 15 of Set 15 | kodinar
# Processing Record 16 of Set 15 | batemans bay
# Processing Record 17 of Set 15 | imbituba
# Processing Record 18 of Set 15 | corn island
# Processing Record 19 of Set 15 | tateyama
# Processing Record 20 of Set 15 | luau
# Processing Record 21 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 15 | tabas
# Processing Record 23 of Set 15 | rokytne
# Processing Record 24 of Set 15 | margate
# Processing Record 25 of Set 15 | bandarbeyla
# Processing Record 26 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 27 of Set 15 | adre
# Processing Record 28 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 29 of Set 15 | drjanovo
# City not found. Skipping...
# Processing Record 30 of Set 15 | tawau
# Processing Record 31 of Set 15 | san miguel
# Processing Record 32 of Set 15 | wanganui
# Processing Record 33 of Set 15 | siedlce
# Processing Record 34 of Set 15 | fallon
# Processing Record 35 of Set 15 | mogadishu
# Processing Record 36 of Set 15 | san pedro
# Processing Record 37 of Set 15 | blagoyevo
# Processing Record 38 of Set 15 | mulchen
# Processing Record 39 of Set 15 | formello
# Processing Record 40 of Set 15 | vangaindrano
# Processing Record 41 of Set 15 | nicoya
# Processing Record 42 of Set 15 | yambio
# Processing Record 43 of Set 15 | tamandare
# Processing Record 44 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 45 of Set 15 | tubuala
# Processing Record 46 of Set 15 | gayny
# Processing Record 47 of Set 15 | santa rosa
# Processing Record 48 of Set 15 | bratsk
# Processing Record 49 of Set 15 | fevik
# Processing Record 50 of Set 15 | college
# Processing Record 1 of Set 16 | kirby
# Processing Record 2 of Set 16 | lac du bonnet
# Processing Record 3 of Set 16 | manono
# Processing Record 4 of Set 16 | shitkino
# Processing Record 5 of Set 16 | viseu
# Processing Record 6 of Set 16 | miquelon
# Processing Record 7 of Set 16 | lubao
# Processing Record 8 of Set 16 | dujuma
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Tutoia      BR  -2.7619  -42.2744     89.58        62         100
# 1      Ushuaia      AR -54.8000  -68.3000     47.86        66          75
# 2   Concepcion      CL -36.8270  -73.0498     69.60        68          75
# 3        Amapa      BR   1.0000  -52.0000     81.72        77          92
# 4  Tuktoyaktuk      CA  69.4541 -133.0374     -2.20        78         100
# 5     Zhigansk      RU  66.7697  123.3711    -32.55       100          97
# 6         Chuy      UY -33.6971  -53.4616     79.66        55          99
# 7      Guozhen      CN  34.3659  107.3590     28.62        70          42
# 8    Hithadhoo      MV  -0.6000   73.0833     82.27        68         100
# 9      Salalah      OM  17.0151   54.0924     75.29        69           0
#
#    Wind Speed Current Description
# 0       11.27          light rain
# 1       23.02       broken clouds
# 2       14.97       broken clouds
# 3        4.05     overcast clouds
# 4       16.11          light snow
# 5        3.24     overcast clouds
# 6       12.64     overcast clouds
# 7        2.68    scattered clouds
# 8        8.34     overcast clouds
# 9        4.61           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
